# %%
#Importando o pandas
import pandas as pd

# %%
#Abrindo o arquivo csv
df = pd.read_csv("campeonato_brasileiro.csv", encoding="UTF-8")

# %%
df.head()
# Out:
#        nome_campeonato  temporada    pais  rodada time_dentro    time_fora  \
# 0  Brasileirão Série A       2019  Brasil      20       Goiás   Fluminense
# 1  Brasileirão Série A       2019  Brasil      18        Avaí     Flamengo
# 2  Brasileirão Série A       2019  Brasil      18       Goiás    Palmeiras
# 3  Brasileirão Série A       2019  Brasil      18    Botafogo  Atlético MG
# 4  Brasileirão Série A       2019  Brasil      18         CSA  Chapecoense
#
#   resultado_final resultado_final_v_d_e  gols_mandante  gols_visitante  ...  \
# 0           3 - 0                     V              3               0  ...
# 1           0 - 3                     D              0               3  ...
# 2           1 - 2                     D              1               2  ...
# 3           2 - 1                     V              2               1  ...
# 4           2 - 0                     V              2               0  ...
#
# ...
