# %%
import pandas as pd
dataset = pd.read_csv("Testes/verificacao_partidas.csv", encoding="UTF-8")

dataset.head()
# Out:
#    posicao_time_dentro  posicao_time_fora  \
# 0                   15                  7
# 1                    5                 19
# 2                   13                 17
# 3                   17                 11
# 4                    2                 20
#
#    media_gols_marcados_por_jogo_time_casa_em_casa  \
# 0                                            1.08
# 1                                            1.31
# 2                                            1.08
# 3                                            0.85
# 4                                            2.25
#
#    media_gols_sofridos_por_jogo_time_casa_em_casa  \
# 0                                            0.92
# 1                                            0.62
# 2                                            0.92
# 3                                            1.00
# 4                                            0.50
#
#    media_gols_sofridos_por_jogo_time_visitante_fora  \
# ...
